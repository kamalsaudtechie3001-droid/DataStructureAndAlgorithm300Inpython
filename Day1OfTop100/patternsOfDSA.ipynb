# %% [markdown]
# # Array and Hashing.
# ✔ Two Sum
#
# ✔ Contains Duplicate
#
# ✔ Product of Array Except Self
#
# ✔ Missing Number
#
# ✔ Majority Element
#
# ✔ Single Number
#
# ✔ Group Anagrams
#
# ✔ Top K Frequent Elements
#
# ✔ Longest Consecutive Sequence
#
# ➡ Pattern: Hash maps, frequency counting, prefix logic

# %% [markdown]
# # Two Pointers
#
# ✔ Valid Palindrome
#
# ✔ Two Sum II
#
# ✔ Container With Most Water
#
# ✔ Remove Element
#
# ✔ Remove Duplicates from Sorted Array
#
# ✔ Trapping Rain Water
#
# ➡ Pattern: Left/right pointers, in-place optimization

# %% [markdown]
# # Sliding Window
#
# ✔ Longest Substring Without Repeating Characters
#
# ✔ Minimum Window Substring
#
# ✔ Maximal Square
#
# ✔ Best Time to Buy and Sell Stock / II
#
# ➡ Pattern: Dynamic window expansion/contraction

# %% [markdown]
# # Stack
#
# ✔ Valid Parentheses
#
# ✔ Min Stack
#
# ✔ Basic Calculator
#
# ✔ Evaluate Division
#
# ➡ Pattern: Monotonic stack, expression parsing

# %% [markdown]
# # Binary Search
#
# ✔ Binary Search
#
# ✔ Find Minimum in Rotated Sorted Array
#
# ✔ Search in Rotated Sorted Array
#
# ✔ Kth Smallest Element in a BST
#
# ✔ Median of Two Sorted Arrays
#
# ➡ Pattern: Search space reduction

# %% [markdown]
# # Linked List
#
# ✔ Reverse Linked List
#
# ✔ Linked List Cycle
#
# ✔ Merge Two Sorted Lists
#
# ✔ Add Two Numbers
#
# ✔ Remove Nth Node From End
#
# ✔ Copy List with Random Pointer
#
# ✔ Reverse Nodes in k-Group
#
# ➡ Pattern: Fast/slow pointers, in-place reversal

# %% [markdown]
# # Trees
#
# ✔ Invert Binary Tree
#
# ✔ Maximum Depth of Binary Tree
#
# ✔ Diameter of Binary Tree
#
# ✔ Symmetric Tree
#
# ✔ Validate BST
#
# ✔ Binary Tree Traversals
#
# ✔ Construct Tree (Pre/In/Post order)
#
# ✔ Flatten Binary Tree
#
# ✔ Right Side View
#
# ➡ Pattern: DFS, BFS, recursion

# %% [markdown]
# # Graphs
#
# ✔ Number of Islands
#
# ✔ Clone Graph
#
# ✔ Course Schedule I & II
#
# ✔ Evaluate Division
#
# ➡ Pattern: BFS, DFS, Topological sort, Union-Find

# %% [markdown]
# # Backtracking
#
# ✔ Subsets
#
# ✔ Permutations
#
# ✔ Combination Sum
#
# ✔ Generate Parentheses
#
# ✔ Word Search / Word Search II
#
# ➡ Pattern: Decision trees, recursion with pruning

# %% [markdown]
# # Dynamic Programming
#
# ✔ Climbing Stairs
#
# ✔ House Robber
#
# ✔ Coin Change
#
# ✔ Word Break
#
# ✔ LIS
#
# ✔ Maximum Subarray
#
# ✔ Minimum Path Sum
#
# ✔ Unique Paths
#
# ➡ Pattern: 1D / 2D DP, state transitions

# %% [markdown]
# # Heap / Priority Queue
#
# ✔ Kth Largest Element
#
# ✔ Merge k Sorted Lists
#
# ✔ Find Median from Data Stream
#
# ➡ Pattern: Min-heap / Max-heap
