# %% [markdown]
# **Optimal approach**:

# %%
#To Calculate the product of the array except the self.

def productElements(nums):
    n = len(nums)
    output = [0] * n
    output[0] = 1
    for i in range(1 ,n):
        output[i] = output[i-1] * nums[i - 1]
    right = 1
    for i in range(n-1 , -1 , -1):
        output[i] *= right
        right *= nums[i]
    
    return output

nums = [1,2,3,4]
ans = productElements(nums)
print(f"The product of the elements is:", ans)
# Out:
# The product of the elements is: [24, 12, 8, 6]

# %% [markdown]
# **Time Complexity** : O(N)
#
# **Space Complexity** : O(N) : We are using the output as a extra array.
